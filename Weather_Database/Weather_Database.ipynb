# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library
import requests 

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=cImperial&APPID=" + weather_api_key 
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=cImperial&APPID=6c1f9ea901c21039b6fb5fcba814d73b

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | nantucket
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | los lunas
# Processing Record 7 of Set 1 | lompoc
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 1 | salalah
# Processing Record 12 of Set 1 | maykor
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | dianopolis
# City not found. Skipping...
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | bria
# Processing Record 19 of Set 1 | aransas pass
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | opuwo
# Processing Record 22 of Set 1 | kuala terengganu
# Processing Record 23 of Set 1 | inongo
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | port lincoln
# Processing Record 32 of Set 1 | lazaro cardenas
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | santo antonio do ica
# Processing Record 37 of Set 1 | sioux lookout
# Processing Record 38 of Set 1 | soe
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | lovozero
# Processing Record 41 of Set 1 | rudnogorsk
# Processing Record 42 of Set 1 | anadyr
# Processing Record 43 of Set 1 | tuatapere
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | saldanha
# Processing Record 47 of Set 1 | alamosa
# Processing Record 48 of Set 1 | mason city
# Processing Record 49 of Set 1 | kununurra
# Processing Record 50 of Set 1 | porto belo
# Processing Record 1 of Set 2 | miyang
# Processing Record 2 of Set 2 | coihaique
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | batemans bay
# Processing Record 5 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | verkhneyarkeyevo
# Processing Record 11 of Set 2 | santa cruz
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | torbay
# Processing Record 16 of Set 2 | lermontovka
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | egvekinot
# Processing Record 20 of Set 2 | vuktyl
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | trapani
# Processing Record 24 of Set 2 | abu kamal
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | numan
# Processing Record 28 of Set 2 | bilibino
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | vanimo
# Processing Record 33 of Set 2 | port hardy
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | constitucion
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | eufaula
# Processing Record 39 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 2 | usinsk
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | beloha
# Processing Record 44 of Set 2 | rodbyhavn
# Processing Record 45 of Set 2 | puerto penasco
# Processing Record 46 of Set 2 | ust-barguzin
# Processing Record 47 of Set 2 | pangnirtung
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | masaka
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | viedma
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | zaysan
# Processing Record 4 of Set 3 | lata
# Processing Record 5 of Set 3 | ancud
# Processing Record 6 of Set 3 | broken hill
# Processing Record 7 of Set 3 | hasaki
# Processing Record 8 of Set 3 | tucuman
# Processing Record 9 of Set 3 | umm kaddadah
# Processing Record 10 of Set 3 | mackenzie
# Processing Record 11 of Set 3 | ixtapa
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | shelburne
# Processing Record 14 of Set 3 | mildura
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | omsukchan
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | mandalgovi
# Processing Record 19 of Set 3 | carnarvon
# Processing Record 20 of Set 3 | honiara
# Processing Record 21 of Set 3 | banda aceh
# Processing Record 22 of Set 3 | laguna
# Processing Record 23 of Set 3 | dinghai
# Processing Record 24 of Set 3 | tual
# Processing Record 25 of Set 3 | tevriz
# Processing Record 26 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | chapada dos guimaraes
# Processing Record 29 of Set 3 | hami
# Processing Record 30 of Set 3 | listvyanka
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | bubaque
# Processing Record 34 of Set 3 | ostrovnoy
# Processing Record 35 of Set 3 | namatanai
# Processing Record 36 of Set 3 | saint-pierre
# Processing Record 37 of Set 3 | hay river
# Processing Record 38 of Set 3 | san policarpo
# Processing Record 39 of Set 3 | aksu
# Processing Record 40 of Set 3 | east london
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | port blair
# Processing Record 43 of Set 3 | dingle
# Processing Record 44 of Set 3 | portland
# Processing Record 45 of Set 3 | michigan city
# Processing Record 46 of Set 3 | uk
# City not found. Skipping...
# Processing Record 47 of Set 3 | brae
# Processing Record 48 of Set 3 | haines junction
# Processing Record 49 of Set 3 | benalla
# Processing Record 50 of Set 3 | ayagoz
# Processing Record 1 of Set 4 | kaabong
# Processing Record 2 of Set 4 | tapejara
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | vostok
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | tayoltita
# Processing Record 7 of Set 4 | praia
# Processing Record 8 of Set 4 | grand gaube
# Processing Record 9 of Set 4 | isetskoye
# Processing Record 10 of Set 4 | chapais
# Processing Record 11 of Set 4 | lukulu
# Processing Record 12 of Set 4 | colmar
# Processing Record 13 of Set 4 | katangli
# Processing Record 14 of Set 4 | riyadh
# Processing Record 15 of Set 4 | yancheng
# Processing Record 16 of Set 4 | lorengau
# Processing Record 17 of Set 4 | weligama
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | beisfjord
# Processing Record 20 of Set 4 | yar-sale
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | igarka
# Processing Record 23 of Set 4 | payakumbuh
# Processing Record 24 of Set 4 | kaitangata
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | krivopolyanye
# City not found. Skipping...
# Processing Record 28 of Set 4 | clyde river
# Processing Record 29 of Set 4 | mount isa
# Processing Record 30 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | manzanillo
# Processing Record 33 of Set 4 | saint-augustin
# Processing Record 34 of Set 4 | hervey bay
# Processing Record 35 of Set 4 | parkes
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | vao
# Processing Record 38 of Set 4 | limon
# Processing Record 39 of Set 4 | kahului
# Processing Record 40 of Set 4 | kpandae
# Processing Record 41 of Set 4 | acolla
# Processing Record 42 of Set 4 | buraydah
# Processing Record 43 of Set 4 | nuuk
# Processing Record 44 of Set 4 | kapfenberg
# Processing Record 45 of Set 4 | isangel
# Processing Record 46 of Set 4 | peniche
# Processing Record 47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | hue
# Processing Record 49 of Set 4 | airai
# Processing Record 50 of Set 4 | nishihara
# Processing Record 1 of Set 5 | tiksi
# Processing Record 2 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | lerwick
# Processing Record 4 of Set 5 | lavrentiya
# Processing Record 5 of Set 5 | qaanaaq
# Processing Record 6 of Set 5 | sorong
# Processing Record 7 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 8 of Set 5 | baiyin
# Processing Record 9 of Set 5 | toamasina
# Processing Record 10 of Set 5 | saskylakh
# Processing Record 11 of Set 5 | westport
# Processing Record 12 of Set 5 | faya
# Processing Record 13 of Set 5 | kearney
# Processing Record 14 of Set 5 | lebu
# Processing Record 15 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 5 | sarangani
# Processing Record 17 of Set 5 | tarrega
# Processing Record 18 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 5 | puruliya
# Processing Record 20 of Set 5 | dundee
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | masvingo
# Processing Record 23 of Set 5 | snezhnogorsk
# Processing Record 24 of Set 5 | evensk
# Processing Record 25 of Set 5 | kristianstad
# Processing Record 26 of Set 5 | gushikawa
# Processing Record 27 of Set 5 | wa
# City not found. Skipping...
# Processing Record 28 of Set 5 | rio gallegos
# Processing Record 29 of Set 5 | genhe
# Processing Record 30 of Set 5 | fort frances
# Processing Record 31 of Set 5 | ugoofaaru
# Processing Record 32 of Set 5 | dhidhdhoo
# Processing Record 33 of Set 5 | vicuna
# Processing Record 34 of Set 5 | pochutla
# Processing Record 35 of Set 5 | yulara
# Processing Record 36 of Set 5 | komsomolskiy
# Processing Record 37 of Set 5 | bogorodskoye
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | moerai
# Processing Record 40 of Set 5 | tonstad
# Processing Record 41 of Set 5 | porto novo
# Processing Record 42 of Set 5 | vilyuysk
# Processing Record 43 of Set 5 | gonzalez
# Processing Record 44 of Set 5 | bonthe
# Processing Record 45 of Set 5 | bilma
# Processing Record 46 of Set 5 | pundaguitan
# Processing Record 47 of Set 5 | bandarbeyla
# Processing Record 48 of Set 5 | warkworth
# Processing Record 49 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 5 | laishevo
# Processing Record 1 of Set 6 | san matias
# Processing Record 2 of Set 6 | leshukonskoye
# Processing Record 3 of Set 6 | alihe
# Processing Record 4 of Set 6 | okhotsk
# Processing Record 5 of Set 6 | pallasovka
# Processing Record 6 of Set 6 | sao felix do xingu
# Processing Record 7 of Set 6 | priiskovyy
# Processing Record 8 of Set 6 | buin
# Processing Record 9 of Set 6 | caravelas
# Processing Record 10 of Set 6 | llanes
# Processing Record 11 of Set 6 | toba tek singh
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | raudeberg
# Processing Record 14 of Set 6 | progreso
# Processing Record 15 of Set 6 | chekhov
# Processing Record 16 of Set 6 | narsaq
# Processing Record 17 of Set 6 | belaya gora
# Processing Record 18 of Set 6 | krasnoselkup
# Processing Record 19 of Set 6 | scarborough
# Processing Record 20 of Set 6 | saint-andre
# Processing Record 21 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 6 | rapar
# Processing Record 23 of Set 6 | tupik
# Processing Record 24 of Set 6 | korhogo
# Processing Record 25 of Set 6 | newtownards
# Processing Record 26 of Set 6 | buala
# Processing Record 27 of Set 6 | chauk
# Processing Record 28 of Set 6 | bemidji
# Processing Record 29 of Set 6 | sorland
# Processing Record 30 of Set 6 | jizan
# Processing Record 31 of Set 6 | nanortalik
# Processing Record 32 of Set 6 | xingyi
# Processing Record 33 of Set 6 | pisco
# Processing Record 34 of Set 6 | falaleu
# City not found. Skipping...
# Processing Record 35 of Set 6 | sao joao da barra
# Processing Record 36 of Set 6 | kashi
# Processing Record 37 of Set 6 | paamiut
# Processing Record 38 of Set 6 | arraial do cabo
# Processing Record 39 of Set 6 | rio grande
# Processing Record 40 of Set 6 | nadvoitsy
# Processing Record 41 of Set 6 | palmer
# Processing Record 42 of Set 6 | prince albert
# Processing Record 43 of Set 6 | gat
# Processing Record 44 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 6 | cacu
# Processing Record 46 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 6 | puerto colombia
# Processing Record 48 of Set 6 | tasiilaq
# Processing Record 49 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 7 | malakal
# Processing Record 2 of Set 7 | kutum
# Processing Record 3 of Set 7 | castro
# Processing Record 4 of Set 7 | vardo
# Processing Record 5 of Set 7 | butaritari
# Processing Record 6 of Set 7 | kulhudhuffushi
# Processing Record 7 of Set 7 | buldana
# Processing Record 8 of Set 7 | manali
# Processing Record 9 of Set 7 | bonavista
# Processing Record 10 of Set 7 | berdyuzhye
# City not found. Skipping...
# Processing Record 11 of Set 7 | sept-iles
# Processing Record 12 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 7 | khatanga
# Processing Record 14 of Set 7 | atambua
# Processing Record 15 of Set 7 | camacha
# Processing Record 16 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 7 | goderich
# Processing Record 18 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 7 | xique-xique
# Processing Record 20 of Set 7 | dunedin
# Processing Record 21 of Set 7 | poronaysk
# Processing Record 22 of Set 7 | mount gambier
# Processing Record 23 of Set 7 | provost
# Processing Record 24 of Set 7 | trelew
# Processing Record 25 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 7 | wilmington
# Processing Record 27 of Set 7 | fort nelson
# Processing Record 28 of Set 7 | ferme-neuve
# Processing Record 29 of Set 7 | mabaruma
# Processing Record 30 of Set 7 | ullapool
# Processing Record 31 of Set 7 | robe
# Processing Record 32 of Set 7 | mar del plata
# Processing Record 33 of Set 7 | richards bay
# Processing Record 34 of Set 7 | peace river
# Processing Record 35 of Set 7 | tabriz
# Processing Record 36 of Set 7 | skovorodino
# Processing Record 37 of Set 7 | nueva imperial
# Processing Record 38 of Set 7 | shitanjing
# Processing Record 39 of Set 7 | pechora
# Processing Record 40 of Set 7 | moree
# Processing Record 41 of Set 7 | gornopravdinsk
# Processing Record 42 of Set 7 | lagunas
# Processing Record 43 of Set 7 | mehamn
# Processing Record 44 of Set 7 | coahuayana
# Processing Record 45 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 7 | rantepao
# Processing Record 47 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 7 | ayan
# Processing Record 49 of Set 7 | pafos
# Processing Record 50 of Set 7 | karaton
# Processing Record 1 of Set 8 | henties bay
# Processing Record 2 of Set 8 | fairbanks
# Processing Record 3 of Set 8 | iskateley
# Processing Record 4 of Set 8 | antofagasta
# Processing Record 5 of Set 8 | ipu
# Processing Record 6 of Set 8 | napier
# Processing Record 7 of Set 8 | baft
# Processing Record 8 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 8 | asau
# Processing Record 10 of Set 8 | najran
# Processing Record 11 of Set 8 | bereda
# Processing Record 12 of Set 8 | adrar
# Processing Record 13 of Set 8 | cap-aux-meules
# Processing Record 14 of Set 8 | lons-le-saunier
# Processing Record 15 of Set 8 | manakara
# Processing Record 16 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 8 | mazatlan
# Processing Record 18 of Set 8 | la baule-escoublac
# Processing Record 19 of Set 8 | sao jose da coroa grande
# Processing Record 20 of Set 8 | samarai
# Processing Record 21 of Set 8 | anchorage
# Processing Record 22 of Set 8 | jamame
# Processing Record 23 of Set 8 | manoharpur
# Processing Record 24 of Set 8 | kambove
# Processing Record 25 of Set 8 | polunochnoye
# Processing Record 26 of Set 8 | hambantota
# Processing Record 27 of Set 8 | ahipara
# Processing Record 28 of Set 8 | tshikapa
# Processing Record 29 of Set 8 | mogadishu
# Processing Record 30 of Set 8 | luderitz
# Processing Record 31 of Set 8 | vestmannaeyjar
# Processing Record 32 of Set 8 | umba
# Processing Record 33 of Set 8 | sarab
# Processing Record 34 of Set 8 | ojinaga
# Processing Record 35 of Set 8 | pingdu
# Processing Record 36 of Set 8 | willmar
# Processing Record 37 of Set 8 | havoysund
# Processing Record 38 of Set 8 | ngunguru
# Processing Record 39 of Set 8 | gonzales
# Processing Record 40 of Set 8 | le port
# Processing Record 41 of Set 8 | zhezkazgan
# Processing Record 42 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 43 of Set 8 | katsuura
# Processing Record 44 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 8 | kathu
# Processing Record 46 of Set 8 | aseri
# Processing Record 47 of Set 8 | buritis
# Processing Record 48 of Set 8 | formosa do rio preto
# Processing Record 49 of Set 8 | coquimbo
# Processing Record 50 of Set 8 | tabuk
# Processing Record 1 of Set 9 | shimoda
# Processing Record 2 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 9 | svetlaya
# Processing Record 5 of Set 9 | presidente epitacio
# Processing Record 6 of Set 9 | prince rupert
# Processing Record 7 of Set 9 | raga
# Processing Record 8 of Set 9 | kizukuri
# Processing Record 9 of Set 9 | tura
# Processing Record 10 of Set 9 | lantawan
# Processing Record 11 of Set 9 | zadonsk
# Processing Record 12 of Set 9 | ust-omchug
# Processing Record 13 of Set 9 | yanji
# Processing Record 14 of Set 9 | saint-francois
# Processing Record 15 of Set 9 | biak
# Processing Record 16 of Set 9 | verkh-usugli
# Processing Record 17 of Set 9 | anito
# Processing Record 18 of Set 9 | aksehir
# Processing Record 19 of Set 9 | rudbar
# Processing Record 20 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 9 | hirara
# Processing Record 22 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 9 | chateaubelair
# Processing Record 24 of Set 9 | aden
# Processing Record 25 of Set 9 | kontagora
# Processing Record 26 of Set 9 | karratha
# Processing Record 27 of Set 9 | naze
# Processing Record 28 of Set 9 | northam
# Processing Record 29 of Set 9 | atar
# Processing Record 30 of Set 9 | minuri
# Processing Record 31 of Set 9 | la ronge
# Processing Record 32 of Set 9 | ituiutaba
# Processing Record 33 of Set 9 | sitka
# Processing Record 34 of Set 9 | zhigansk
# Processing Record 35 of Set 9 | hovd
# Processing Record 36 of Set 9 | vila do maio
# Processing Record 37 of Set 9 | khandyga
# Processing Record 38 of Set 9 | staryy nadym
# Processing Record 39 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 9 | katherine
# Processing Record 41 of Set 9 | mantua
# Processing Record 42 of Set 9 | shubarkuduk
# Processing Record 43 of Set 9 | te anau
# Processing Record 44 of Set 9 | mayo
# Processing Record 45 of Set 9 | padang
# Processing Record 46 of Set 9 | santa fe
# Processing Record 47 of Set 9 | marfino
# Processing Record 48 of Set 9 | kruisfontein
# Processing Record 49 of Set 9 | kenai
# Processing Record 50 of Set 9 | deputatskiy
# Processing Record 1 of Set 10 | akyab
# Processing Record 2 of Set 10 | doctor juan leon mallorquin
# Processing Record 3 of Set 10 | port macquarie
# Processing Record 4 of Set 10 | kuytun
# Processing Record 5 of Set 10 | mancora
# Processing Record 6 of Set 10 | balaipungut
# Processing Record 7 of Set 10 | hualmay
# Processing Record 8 of Set 10 | paciran
# Processing Record 9 of Set 10 | sahuaripa
# Processing Record 10 of Set 10 | birjand
# Processing Record 11 of Set 10 | necochea
# Processing Record 12 of Set 10 | ayorou
# Processing Record 13 of Set 10 | yantal
# Processing Record 14 of Set 10 | los llanos de aridane
# Processing Record 15 of Set 10 | lasa
# Processing Record 16 of Set 10 | nouadhibou
# Processing Record 17 of Set 10 | christchurch
# Processing Record 18 of Set 10 | san patricio
# Processing Record 19 of Set 10 | la palma
# Processing Record 20 of Set 10 | sylva
# Processing Record 21 of Set 10 | radcliff
# Processing Record 22 of Set 10 | oranjemund
# Processing Record 23 of Set 10 | morant bay
# Processing Record 24 of Set 10 | male
# Processing Record 25 of Set 10 | kavieng
# Processing Record 26 of Set 10 | milkovo
# Processing Record 27 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 28 of Set 10 | belomorsk
# Processing Record 29 of Set 10 | aklavik
# Processing Record 30 of Set 10 | havre-saint-pierre
# Processing Record 31 of Set 10 | waterloo
# Processing Record 32 of Set 10 | klaksvik
# Processing Record 33 of Set 10 | waddan
# Processing Record 34 of Set 10 | guigue
# Processing Record 35 of Set 10 | dadiangas
# City not found. Skipping...
# Processing Record 36 of Set 10 | djenne
# Processing Record 37 of Set 10 | wewak
# Processing Record 38 of Set 10 | emerald
# Processing Record 39 of Set 10 | bergen
# Processing Record 40 of Set 10 | muros
# Processing Record 41 of Set 10 | norfolk
# Processing Record 42 of Set 10 | minab
# Processing Record 43 of Set 10 | boyuibe
# Processing Record 44 of Set 10 | san cristobal
# Processing Record 45 of Set 10 | palembang
# Processing Record 46 of Set 10 | yanam
# Processing Record 47 of Set 10 | maple creek
# Processing Record 48 of Set 10 | sechura
# Processing Record 49 of Set 10 | pitimbu
# Processing Record 50 of Set 10 | ketchikan
# Processing Record 1 of Set 11 | semey
# Processing Record 2 of Set 11 | ayna
# Processing Record 3 of Set 11 | beringovskiy
# Processing Record 4 of Set 11 | thinadhoo
# Processing Record 5 of Set 11 | umm lajj
# Processing Record 6 of Set 11 | sisimiut
# Processing Record 7 of Set 11 | hamilton
# Processing Record 8 of Set 11 | kailua
# Processing Record 9 of Set 11 | marrakesh
# Processing Record 10 of Set 11 | uvat
# Processing Record 11 of Set 11 | sharlyk
# Processing Record 12 of Set 11 | krasnovishersk
# Processing Record 13 of Set 11 | jadu
# Processing Record 14 of Set 11 | seoul
# Processing Record 15 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 16 of Set 11 | cockburn town
# Processing Record 17 of Set 11 | khor
# Processing Record 18 of Set 11 | turochak
# Processing Record 19 of Set 11 | marystown
# Processing Record 20 of Set 11 | bairiki
# Processing Record 21 of Set 11 | anloga
# Processing Record 22 of Set 11 | cayeli
# Processing Record 23 of Set 11 | svetlogorsk
# Processing Record 24 of Set 11 | chenzhou
# Processing Record 25 of Set 11 | tarragona
# Processing Record 26 of Set 11 | talcahuano
# Processing Record 27 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 11 | thompson
# Processing Record 29 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 11 | plettenberg bay
# Processing Record 31 of Set 11 | sedhiou
# Processing Record 32 of Set 11 | sabang
# Processing Record 33 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 11 | mandurah
# Processing Record 35 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 11 | wagar
# Processing Record 37 of Set 11 | fortuna
# Processing Record 38 of Set 11 | ilulissat
# Processing Record 39 of Set 11 | dharmavaram
# Processing Record 40 of Set 11 | yopal
# Processing Record 41 of Set 11 | batavia
# Processing Record 42 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 11 | odesskoye
# Processing Record 44 of Set 11 | yabrud
# Processing Record 45 of Set 11 | alyangula
# Processing Record 46 of Set 11 | santa maria
# Processing Record 47 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 48 of Set 11 | benguela
# Processing Record 49 of Set 11 | tautira
# Processing Record 50 of Set 11 | pierre
# Processing Record 1 of Set 12 | kismayo
# Processing Record 2 of Set 12 | tessalit
# Processing Record 3 of Set 12 | barranca
# Processing Record 4 of Set 12 | micheweni
# Processing Record 5 of Set 12 | puerto baquerizo moreno
# Processing Record 6 of Set 12 | hofn
# Processing Record 7 of Set 12 | pangkalanbuun
# Processing Record 8 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 9 of Set 12 | praya
# Processing Record 10 of Set 12 | silivainiotika
# City not found. Skipping...
# Processing Record 11 of Set 12 | prokopyevsk
# Processing Record 12 of Set 12 | veseloyarsk
# Processing Record 13 of Set 12 | kushiro
# Processing Record 14 of Set 12 | kamaishi
# Processing Record 15 of Set 12 | tonantins
# Processing Record 16 of Set 12 | luwingu
# Processing Record 17 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 18 of Set 12 | maldonado
# Processing Record 19 of Set 12 | salaga
# Processing Record 20 of Set 12 | bethanien
# Processing Record 21 of Set 12 | barra do corda
# Processing Record 22 of Set 12 | arlit
# Processing Record 23 of Set 12 | hoi an
# Processing Record 24 of Set 12 | bowen
# Processing Record 25 of Set 12 | penarroya-pueblonuevo
# Processing Record 26 of Set 12 | alice springs
# Processing Record 27 of Set 12 | benjamin constant
# Processing Record 28 of Set 12 | ruwi
# Processing Record 29 of Set 12 | georgiyevka
# Processing Record 30 of Set 12 | nioro
# Processing Record 31 of Set 12 | ambatondrazaka
# Processing Record 32 of Set 12 | aykhal
# Processing Record 33 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 12 | wad rawah
# Processing Record 35 of Set 12 | oulu
# Processing Record 36 of Set 12 | vrangel
# Processing Record 37 of Set 12 | gillette
# Processing Record 38 of Set 12 | aljezur
# Processing Record 39 of Set 12 | labuan
# Processing Record 40 of Set 12 | marsa matruh
# Processing Record 41 of Set 12 | poum
# Processing Record 42 of Set 12 | bela
# Processing Record 43 of Set 12 | hollister
# Processing Record 44 of Set 12 | toora-khem
# Processing Record 45 of Set 12 | kastornoye
# Processing Record 46 of Set 12 | emba
# Processing Record 47 of Set 12 | piacabucu
# Processing Record 48 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 49 of Set 12 | ulladulla
# Processing Record 50 of Set 12 | sapernoye
# Processing Record 1 of Set 13 | slave lake
# Processing Record 2 of Set 13 | vyazemskiy
# Processing Record 3 of Set 13 | hastings
# Processing Record 4 of Set 13 | cayenne
# Processing Record 5 of Set 13 | bolonchen
# City not found. Skipping...
# Processing Record 6 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 7 of Set 13 | miyako
# Processing Record 8 of Set 13 | takoradi
# Processing Record 9 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 10 of Set 13 | salinas
# Processing Record 11 of Set 13 | san vicente
# Processing Record 12 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 13 | misratah
# Processing Record 14 of Set 13 | sobolevo
# Processing Record 15 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 13 | namibe
# Processing Record 17 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 18 of Set 13 | maarianhamina
# Processing Record 19 of Set 13 | manjeshwar
# Processing Record 20 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 13 | martinsville
# Processing Record 22 of Set 13 | cordoba
# Processing Record 23 of Set 13 | teguldet
# Processing Record 24 of Set 13 | turinskaya sloboda
# Processing Record 25 of Set 13 | bobo dioulasso
# Processing Record 26 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 13 | cao bang
# Processing Record 28 of Set 13 | alexandria
# Processing Record 29 of Set 13 | elizabeth city
# Processing Record 30 of Set 13 | husavik
# Processing Record 31 of Set 13 | horodyshche
# Processing Record 32 of Set 13 | talara
# Processing Record 33 of Set 13 | nizip
# Processing Record 34 of Set 13 | badvel
# Processing Record 35 of Set 13 | dawei
# Processing Record 36 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 13 | aranos
# Processing Record 38 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 13 | kingsport
# Processing Record 40 of Set 13 | glens falls
# Processing Record 41 of Set 13 | chicama
# Processing Record 42 of Set 13 | rabak
# Processing Record 43 of Set 13 | flinders
# Processing Record 44 of Set 13 | sinnamary
# Processing Record 45 of Set 13 | jinka
# Processing Record 46 of Set 13 | black forest
# Processing Record 47 of Set 13 | dali
# Processing Record 48 of Set 13 | bridlington
# Processing Record 49 of Set 13 | porto santo
# Processing Record 50 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 14 | sao sebastiao
# Processing Record 2 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 14 | belyy yar
# Processing Record 4 of Set 14 | kachiry
# Processing Record 5 of Set 14 | jishou
# Processing Record 6 of Set 14 | bambanglipuro
# Processing Record 7 of Set 14 | kitimat
# Processing Record 8 of Set 14 | srednekolymsk
# Processing Record 9 of Set 14 | huarmey
# Processing Record 10 of Set 14 | umm ruwabah
# City not found. Skipping...
# Processing Record 11 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 12 of Set 14 | pajan
# Processing Record 13 of Set 14 | puerto escondido
# Processing Record 14 of Set 14 | avera
# Processing Record 15 of Set 14 | burns lake
# Processing Record 16 of Set 14 | kijang
# Processing Record 17 of Set 14 | aksarka
# Processing Record 18 of Set 14 | wolgast
# Processing Record 19 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 14 | kendari
# Processing Record 21 of Set 14 | ambon
# Processing Record 22 of Set 14 | gizo
# Processing Record 23 of Set 14 | homer
# Processing Record 24 of Set 14 | mtwango
# Processing Record 25 of Set 14 | sola
# Processing Record 26 of Set 14 | monte escobedo
# Processing Record 27 of Set 14 | kurilsk
# Processing Record 28 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 14 | mangrol
# Processing Record 30 of Set 14 | koslan
# Processing Record 31 of Set 14 | lacdayan
# Processing Record 32 of Set 14 | singaraja
# Processing Record 33 of Set 14 | boguchany
# Processing Record 34 of Set 14 | honolulu
# Processing Record 35 of Set 14 | rocha
# Processing Record 36 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 14 | kyzyl-suu
# Processing Record 38 of Set 14 | wloclawek
# Processing Record 39 of Set 14 | gaya
# Processing Record 40 of Set 14 | uglich
# Processing Record 41 of Set 14 | lahij
# Processing Record 42 of Set 14 | zamora
# Processing Record 43 of Set 14 | prosec
# Processing Record 44 of Set 14 | khartoum
# Processing Record 45 of Set 14 | leningradskiy
# Processing Record 46 of Set 14 | issia
# Processing Record 47 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 14 | castro alves
# Processing Record 49 of Set 14 | dekar
# Processing Record 50 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 1 of Set 15 | lexington
# Processing Record 2 of Set 15 | masuguru
# Processing Record 3 of Set 15 | luanda
# Processing Record 4 of Set 15 | kozhevnikovo
# Processing Record 5 of Set 15 | alta floresta
# Processing Record 6 of Set 15 | aracruz
# Processing Record 7 of Set 15 | lolodorf
# Processing Record 8 of Set 15 | santa ana
# Processing Record 9 of Set 15 | lethem
# Processing Record 10 of Set 15 | kidal
# Processing Record 11 of Set 15 | dalnerechensk
# Processing Record 12 of Set 15 | barra do garcas
# Processing Record 13 of Set 15 | meilu
# City not found. Skipping...
# Processing Record 14 of Set 15 | college
# Processing Record 15 of Set 15 | verkhniy landekh
# Processing Record 16 of Set 15 | kodinsk
# Processing Record 17 of Set 15 | sommerda
# Processing Record 18 of Set 15 | ust-tsilma
# Processing Record 19 of Set 15 | margate
# Processing Record 20 of Set 15 | zilair
# Processing Record 21 of Set 15 | krutikha
# Processing Record 22 of Set 15 | mendi
# Processing Record 23 of Set 15 | madera
# Processing Record 24 of Set 15 | santa cruz de las flores
# Processing Record 25 of Set 15 | korla
# Processing Record 26 of Set 15 | gladstone
# Processing Record 27 of Set 15 | xinan
# Processing Record 28 of Set 15 | veraval
# Processing Record 29 of Set 15 | puquio
# Processing Record 30 of Set 15 | qabis
# City not found. Skipping...
# Processing Record 31 of Set 15 | buenos aires
# Processing Record 32 of Set 15 | kushmurun
# Processing Record 33 of Set 15 | kenora
# Processing Record 34 of Set 15 | san quintin
# Processing Record 35 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 36 of Set 15 | bunia
# Processing Record 37 of Set 15 | agirish
# Processing Record 38 of Set 15 | tena
# Processing Record 39 of Set 15 | surt
# Processing Record 40 of Set 15 | traralgon
# Processing Record 41 of Set 15 | sur
# Processing Record 42 of Set 15 | guerrero negro
# Processing Record 43 of Set 15 | mocuba
# Processing Record 44 of Set 15 | baruun-urt
# Processing Record 45 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 15 | olafsvik
# Processing Record 47 of Set 15 | makat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vaini      TO -21.2000 -175.2000    296.24        78          75
# 1  Norman Wells      CA  65.2820 -126.8329    283.17        93          90
# 2     Nantucket      US  41.2835  -70.0995    295.35        95          29
# 3     Upernavik      GL  72.7868  -56.1549    278.78        73          16
# 4     Jamestown      US  42.0970  -79.2353    301.95        57           1
# 5     Los Lunas      US  34.8062 -106.7334    310.25        14          90
# 6        Lompoc      US  34.6391 -120.4579    304.83        69           1
# 7   New Norfolk      AU -42.7826  147.0587    285.88        70          14
# 8         Kapaa      US  22.0752 -159.3190    302.33        66          20
# 9       Salalah      OM  17.0151   54.0924    298.20       100          90
#
#    Wind Speed      Current Description
# 0        5.66            broken clouds
# 1        5.66               light rain
# 2        4.06         scattered clouds
# 3        4.97               few clouds
# 4        4.12                clear sky
# 5        0.45          overcast clouds
# 6        6.69                     mist
# 7        0.89               few clouds
# 8        1.34               few clouds
# 9        1.54  light intensity drizzle

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
